# %%
import requests

# %%
response = requests.get("https://www.nokia.com/phones/en_int/security-updates")

# %%
import bs4

# %%
soup = bs4.BeautifulSoup(response.text, "lxml")

# %%
phone = soup.select("script")[6]

# %%
phone
# Out:
# <script>
# ...
